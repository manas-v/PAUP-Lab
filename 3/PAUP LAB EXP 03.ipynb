# %% [markdown]
# ### Q.3. Convert the categorical data into numerical dataset in a given business scenario and further select the important features from the dataset.
# #### a. Find out the detail of the dataset to data type of dataset.
# #### b. Apply suitable technique to convert the categorical data into numerical dataset.
# #### c. Check all features and find out the important features from all features.

# %% [markdown]
# ### Dataset
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns: CRIM - per capita crime rate by town. ZN - proportion of residential land zoned for lots over 25,000 sq.
#
# Link: https://www.kaggle.com/prasadperera/the-boston-housing-dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("Boston.csv")

# %%
df=df.drop(["Unnamed: 0"],axis=1)

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.info()#no missing data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df["chas"].value_counts()
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# %matplotlib inline

# %%
df.hist(bins=50,figsize=(60,60))
plt.show()

# %%
#X=df.drop(["medv"],axis=1)

# %%
#Y=df["medv"]

# %%
train,test=train_test_split(df,test_size=0.20,random_state=42)

# %% [markdown]
# If we coinsider the chas column most of the values are zero so if in the training  sets all the values
# zero then our model will not get the fact that there is "1" also as a possible value so to avoid that
# we will use stratified random sampling for the chas column

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split=StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)

# %%
for train_index,test_index in split.split(df,df["chas"]):
    strat_train=df.loc[train_index]
    strat_test=df.loc[test_index]

# %%
strat_train["chas"].value_counts()
# Out:
# 0    376
# 1     28
# Name: chas, dtype: int64

# %%
 strat_test["chas"].value_counts()
# Out:
# 0    95
# 1     7
# Name: chas, dtype: int64

# %%
95/7
# Out:
# 13.571428571428571

# %%
376/28
# Out:
# 13.428571428571429

# %% [markdown]
# # Correlation

# %%
correlation_matrix=df.corr()

# %%
print(correlation_matrix)
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
from pandas.plotting import scatter_matrix

# %%
attributes=["rm","zn","ptratio","lstat"]
scatter_matrix(df[attributes],figsize=(20,20))
# Out:
# array([[<AxesSubplot:xlabel='rm', ylabel='rm'>,
#         <AxesSubplot:xlabel='zn', ylabel='rm'>,
#         <AxesSubplot:xlabel='ptratio', ylabel='rm'>,
#         <AxesSubplot:xlabel='lstat', ylabel='rm'>],
#        [<AxesSubplot:xlabel='rm', ylabel='zn'>,
#         <AxesSubplot:xlabel='zn', ylabel='zn'>,
#         <AxesSubplot:xlabel='ptratio', ylabel='zn'>,
#         <AxesSubplot:xlabel='lstat', ylabel='zn'>],
#        [<AxesSubplot:xlabel='rm', ylabel='ptratio'>,
#         <AxesSubplot:xlabel='zn', ylabel='ptratio'>,
#         <AxesSubplot:xlabel='ptratio', ylabel='ptratio'>,
#         <AxesSubplot:xlabel='lstat', ylabel='ptratio'>],
#        [<AxesSubplot:xlabel='rm', ylabel='lstat'>,
#         <AxesSubplot:xlabel='zn', ylabel='lstat'>,
#         <AxesSubplot:xlabel='ptratio', ylabel='lstat'>,
#         <AxesSubplot:xlabel='lstat', ylabel='lstat'>]], dtype=object)

# %%
df.plot(kind="scatter",x="rm",y="medv")
# Out:
# <AxesSubplot:xlabel='rm', ylabel='medv'>

# %% [markdown]
# # Different attribute combinations

# %%
df["txp"]=df["tax"]/df["rm"]

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv        txp
# 0       15.3  396.90   4.98  24.0  45.019011
# ...

# %%
correlation_matrix=df.corr()

# %%
print(correlation_matrix)
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# ## Scikit-learn Design

# %% [markdown]
# Primarily three types of objects:
#
#
# 1.Estimator-->it estimates some parameter based on dataset.for ex-imputer
#               it has a fit method and transform method
#               fit method-fits the dataset and calculates internal parameters
#
#
# 2.Transformer-->transform method takes input and returns output based on the
#                  leartnings of fit() method,also has a convenience method called
#                  fit_transform() which fits and then transforms
#
#
# 3.Predictor-->LinearRegressionmodel() is an example of predictor.this has fit and predict
#               and also has a score function to evaluate the prediction

# %% [markdown]
# # Feature Scaling

# %% [markdown]
# Two types of scaling methods are there:
#
#     1.Min-max scaler(Normalization)
#     (value-min)/(max-min)
#     sklearn provides a class called MinMaxScaler for this
#
#     2.standardized scaler
#       (value-mean)/sd
#       here sklearn provides a class called StandardScaler

# %% [markdown]
# ## Creating Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# %%
from sklearn.preprocessing import StandardScaler

# %%
my_pipeline=Pipeline([
    ('imputer',SimpleImputer(strategy="median")),
    #we can add as many things we want....
    ('stdscaler',StandardScaler()),
])

# %%
a=my_pipeline.fit_transform(strat_X_train)

# %%
b=my_pipeline.fit_transform(strat_X_test)

# %%
strat_X_train=strat_train.drop(["medv"],axis=1)

# %%
strat_Y_train=strat_train["medv"]

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(a,strat_Y_train)
# Out:
# LinearRegression()

# %%
a
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, ..., -0.97491834,
#          0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, ..., -0.69277865,
#          0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.44624347,  0.81480158],
#        ...,
#        [-0.43525657, -0.4898311 , -1.23083158, ..., -0.22254583,
#          0.41831233, -1.27603303],
#        [ 0.14210728, -0.4898311 ,  0.98336806, ...,  0.81196637,
#         -3.15239177,  0.73869575],
#        [-0.43974024, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.41070422,  0.09940681]])

# %%
strat_X_test=strat_test.drop(["medv"],axis=1)

# %%
strat_Y_test=strat_test["medv"]

# %%
prediction=model.predict(b)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(strat_Y_test,prediction)
# Out:
# 17.878011421887116

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model2= DecisionTreeRegressor()

# %%
model2.fit(a,strat_Y_train)
# Out:
# DecisionTreeRegressor()

# %%
prediction2=model2.predict(b)

# %%
mean_squared_error(strat_Y_test,prediction2)
# Out:
# 20.508921568627454

# %%
model= DecisionTreeRegressor()

# %%
model.fit(a,strat_Y_train)
# Out:
# DecisionTreeRegressor()

# %%
prediction2=model.predict(b)

# %%
mean_squared_error(strat_Y_test,prediction2)
# Out:
# 19.63019607843137

# %% [markdown]
# # Using a better evaluation technique

# %%
from sklearn.model_selection import cross_val_score

# %%
scores=cross_val_score(model,strat_X_test,strat_Y_test,scoring="neg_mean_squared_error",cv=10)

# %%
scores
# Out:
# array([-25.86181818, -17.66909091, -71.511     , -74.074     ,
#        -14.976     , -14.479     , -54.349     , -18.056     ,
#        -12.138     , -48.607     ])

# %%
rmse_scores=np.sqrt(-scores)

# %%
rmse_scores
# Out:
# array([5.08545162, 4.20346178, 8.45641768, 8.60662535, 3.86988372,
#        3.80512812, 7.37217743, 4.24923523, 3.48396326, 6.97187206])

# %%
np.mean(rmse_scores)
# Out:
# 5.610421624135631

# %%
np.std(rmse_scores)
# Out:
# 1.9223059352044434

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor()

# %%
from joblib import dump,load
dump(model,"Dragon.joblib")
# Out:
# ['Dragon.joblib']

# %%
from sklearn.linear_model import Ridge,Lasso

# %%
model5=Ridge(alpha=0.01)

# %%
model5.fit(a,strat_Y_train)
# Out:
# Ridge(alpha=0.01)

# %%
prediction5=model5.predict(b)

# %%
mean_squared_error(strat_Y_test,prediction5)
# Out:
# 17.8779115087183

# %%
model6=Lasso(alpha=0.01)

# %%
model6.fit(a,strat_Y_train)
# Out:
# Lasso(alpha=0.01)

# %%
prediction6=model6.predict(b)

# %%
mean_squared_error(strat_Y_test,prediction6)
# Out:
# 17.882749126915137

# %%
scores5=cross_val_score(model5,b,strat_Y_test,scoring="neg_mean_squared_error",cv=5)

# %%
scores5.mean()
# Out:
# -20.701350019730036

# %%
rmse5=np.sqrt(-scores5)

# %%
rmse5
# Out:
# array([5.56453141, 4.62062651, 5.4321547 , 3.56173142, 2.99971924])

# %%
rmse5.mean()#for ridge
# Out:
# 4.435752656251282

# %%
scores6=cross_val_score(model6,b,strat_Y_test,scoring="neg_mean_squared_error",cv=5)

# %%
rmse6=np.sqrt(-scores6)

# %%
rmse6.mean()#for lasso
# Out:
# 4.395452475107474
